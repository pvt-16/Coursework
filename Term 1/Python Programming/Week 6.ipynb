# %%
listOfNumbers = [1,3,8,5,6]

# %%
largest = -1
for num in listOfNumbers:
  if num> largest:
    largest = num
print(largest)
# Out:
# 8

# %%
def getLargest(numList, lenList):
  if len(numList) ==1 :
    return numList[0]
    
  largest = getLargest(numList[1:])

# %%
listOfNumbers[1:]
# Out:
# [3, 8, 5, 6]

# %%
ssg

# %% [markdown]
# **Assg**

# %%
def crazyIter(x):
  if x == 0:
    return -1
  elif x == 1:
    return -2
  elif x == 2:
    return -3
  else
    
  print (crazyIter(x-1))

# %%
sum(listOfNumbers[2:5])
# Out:
# 19

# %%
crazyIter(5)

# %%
res = 0
def sumNum(arr):

  if len(arr) ==1:
    return arr[0]
  
  res = arr[0] + sumNum(arr[1:])
  return res

# %%
print(sumNum([5,4,3,2,1]))
# Out:
# 15
